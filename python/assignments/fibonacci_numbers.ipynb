# %%
fibo = 56
x, y = 0, 1
fibo_list = []
while x + y < fibo:
  x, y = y, x + y
  fibo_list.append(y)
print(f"Fibonacci numbers: {fibo_list}")
# Out:
# Fibonacci numbers: [1, 2, 3, 5, 8, 13, 21, 34, 55]
