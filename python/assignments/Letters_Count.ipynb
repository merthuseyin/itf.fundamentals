# %%
def letter_count(sent):
  result = {}
  for i in list(sent):
    result[i] = list(sent).count(i)
  print (result, sep=" ")
letter_count("hippo runs to us!")
# Out:
# {'h': 1, 'i': 1, 'p': 2, 'o': 2, ' ': 3, 'r': 1, 'u': 2, 'n': 1, 's': 2, 't': 1, '!': 1}
